# %% [markdown]
# <a href="https://colab.research.google.com/github/sidparab/SHALA2020_New/blob/master/DS_L3_20_April_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.tail(10)
# Out:
#      Unnamed: 0  ...            actor5
# 590         591  ...        Ben Vereen
# 591         592  ...       Bob Balaban
# 592         593  ...     George Gaynes
# 593         594  ...   Lance Henriksen
# 594         595  ...  Steve Guttenberg
# 595         596  ...       Jack Bailey
# 596         597  ...       Rachel True
# 597         598  ...    Randy McDowell
# 598         599  ...       Ian McNeice
# 599         600  ...    Adam G. Sevani
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
print(movies.corr())
# Draw the heatmap 
plt.figure(figsize=(10,10))
sns.heatmap(movies.corr())
# Out:
#                 Unnamed: 0   runtime  ...  critics_score  audience_score
# Unnamed: 0        1.000000 -0.045146  ...       0.003937        0.012582
# runtime          -0.045146  1.000000  ...       0.169494        0.172237
# thtr_rel_year    -0.000639 -0.124754  ...      -0.096445       -0.062610
# thtr_rel_month    0.005468  0.215274  ...       0.047717        0.034901
# thtr_rel_day      0.046227  0.033998  ...       0.023837        0.033812
# dvd_rel_year     -0.000382 -0.088603  ...       0.009554       -0.073794
# dvd_rel_month    -0.015944 -0.036916  ...       0.041502        0.070543
# dvd_rel_day       0.024857  0.021001  ...      -0.024717        0.019294
# imdb_rating       0.027596  0.261153  ...       0.770764        0.865149
# imdb_num_votes    0.045508  0.342462  ...       0.200657        0.288328
# critics_score     0.003937  0.169494  ...       1.000000        0.710695
# audience_score    0.012582  0.172237  ...       0.710695        1.000000
#
# [12 rows x 12 columns]

# %%
# Creating a mask for removing duplicates 
plt.figure(figsize=(10,10))
mask = np.zeros_like(movies.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(movies.corr(), vmin = -1, cmap='coolwarm', annot=True, mask = mask)

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
train.hist(figsize=(15,15))
# Find out the redundant features 
# EmployeeCount, ID
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6396a9b9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6396b137b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6396ce9a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6396ccf7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f639726ce48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f639e488390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f639e423eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6396b7f668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6396b7f6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6396864b70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6396895dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63967da048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f639680a2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63967bd550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63967737b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6396727a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63966dbc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f639670fef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63966d0198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6396684400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f639663b0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63965ed438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f639659e7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63965d1b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6396584eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6396544278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63964f55f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63964a4978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6396458cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f639641a0b8>]],
#       dtype=object)

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
sns.regplot(x = movies["imdb_rating"], 
            y = movies["audience_score"], ci = 95) # ci = None will not display the confidence interval

# %%
sns.regplot(x = movies["imdb_rating"], 
            y = movies["audience_score"], 
            fit_reg=False, scatter_kws={"color":"red", "alpha":0.3})

# %%
# Change marker of the scatter plot
sns.regplot(x = movies["imdb_rating"], 
            y = movies["audience_score"], 
            marker="+", fit_reg=False, scatter_kws={"color":"red", "alpha":0.5, "s":100})

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
sns.regplot(x = df["petal_length"], 
            y = df["petal_width"], ci = 95) # ci = None will not display the confidence interval

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot(x = "petal_length", 
            y = "petal_width",data=df, hue='species')   #From assignment solution

# %%
# Move the legend to an empty part of the plot
sns.lmplot(x = "petal_length", 
            y = "petal_width",data=df, hue='species') 
plt.legend(loc='lower right')

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset 
df = sns.load_dataset('iris')
plt.subplot(2,2,1)
p1=sns.kdeplot(df['sepal_width'], shade=True, color="r")
plt.subplot(2,2,2)
p1=sns.kdeplot(df['sepal_length'], shade=True, color="g")
plt.subplot(2,2,3)
p1=sns.kdeplot(df['petal_width'], shade=True, color="b")
plt.subplot(2,2,4)
p1=sns.kdeplot(df['petal_length'], shade=True, color="m")

# %%
plt.subplot(2,2,1)
p1=sns.kdeplot(df['sepal_width'], shade=True, color="r",cumulative=True)
plt.subplot(2,2,2)
p1=sns.kdeplot(df['sepal_length'], shade=True, color="g",cumulative=True)
plt.subplot(2,2,3)
p1=sns.kdeplot(df['petal_width'], shade=True, color="b",cumulative=True)
plt.subplot(2,2,4)
p1=sns.kdeplot(df['petal_length'], shade=True, color="m",cumulative=True)

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots 
# plot
# Change the color of each group
sns.violinplot(x=df["species"], y=df["sepal_length"])

# %%
# !git clone https://github.com/sidparab/SHALA2020_New.git
# Out:
# Cloning into 'SHALA2020_New'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.
